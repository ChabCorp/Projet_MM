# %%
import matplotlib.pyplot as plt
import pandas as pd 
import os 
from tqdm import tqdm

# %%
plt.figure(figsize=(10, 10))
nrj = pd.read_csv('energy.xvg', sep='  ', header=None)
nrj.columns = ['time', 'potential', 'kinetic', 'total']
nrj.plot(x='time', y=['potential', 'kinetic', 'total'])
plt.title('Energy')
plt.xlabel('Time (ps)')
plt.ylabel('Energy (kJ/mol)')
plt.legend(['Potential', 'Kinetic', 'Total'])
plt.savefig('energy.png', dpi=500)
plt.show()
# Out:
# C:\Users\Tom\AppData\Local\Temp\ipykernel_22236\2386536392.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   nrj = pd.read_csv('energy.xvg', sep='  ', header=None)

# %%
temp = pd.read_csv('temperature.xvg', sep='  ', header=None)
temp.columns = ['time', 'temperature']
temp.plot(x='time', y='temperature')
plt.title('Temperature')
plt.xlabel('Time (ps)')
plt.ylabel('Temperature (K)')
plt.legend(['Temperature'])
plt.savefig('temperature.png', dpi=500)
plt.show()
# Out:
# C:\Users\Tom\AppData\Local\Temp\ipykernel_22236\3916944794.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   temp = pd.read_csv('temperature.xvg', sep='  ', header=None)

# %%
press = pd.read_csv('pression.xvg', sep='  ', header=None, index_col=False)
press.columns = ['time', 'pression']
press.plot(x='time', y='pression')
plt.title('Pression')
plt.xlabel('Time (ps)')
plt.ylabel('Pression (bar)')
plt.legend(['Pression'])
plt.savefig('pression.png', dpi=500)
plt.show()
press
# Out:
# C:\Users\Tom\AppData\Local\Temp\ipykernel_22236\383945757.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   press = pd.read_csv('pression.xvg', sep='  ', header=None, index_col=False)
#      time    pression
# 0     0.0  219.783218
# 1    10.0   80.306702
# 2    20.0    4.190460
# 3    30.0   27.284546
# 4    40.0  -73.879044
# 5    50.0   22.270355
# 6    60.0  -49.751656
# 7    70.0  147.350662
# 8    80.0   63.692764
# 9    90.0  -22.246826
# 10  100.0  -51.642181

# %%
rmsf = pd.read_csv('rmsf.xvg', sep='  ', header=None, index_col=False)
rmsf.columns = ['residue', 'rmsf']
rmsf.plot(x='residue', y='rmsf')
plt.title('RMSF')
plt.xlabel('Residue')
plt.ylabel('RMSF (nm)')
plt.legend(['RMSF'])
plt.savefig('rmsf.png', dpi=500)
plt.show()
# Out:
# C:\Users\Tom\AppData\Local\Temp\ipykernel_22236\1884232683.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   rmsf = pd.read_csv('rmsf.xvg', sep='  ', header=None, index_col=False)
